# %%
import requests
import pandas as pd
            
def load_data():
    header = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36",
            "X-Requested-With": "XMLHttpRequest"
            }
    r = requests.get("https://www.iplt20.com/stats/2014/most-centuries", headers=header)
    return pd.read_html(r.text)

df = load_data()

length = len(df)

print(length)

df[0]
# Out:
# 1
#    POS            PLAYER  Mat  Inns  NO  Runs  ...   BF      SR  100  50  4s  6s
# 0    1  Virender  Sehwag   17    17   0   455  ...  315  144.44    1   1  56  18
# 1    2    Lendl  Simmons    8     8   1   394  ...  291  135.39    1   3  43  14
# 2    3  Wriddhiman  Saha   17    13   2   362  ...  249  145.38    1   2  33  18
#
# [3 rows x 14 columns]

# %%
import pandas as pd

df = pd.read_html("https://en.wikipedia.org/wiki/ICC_Player_Rankings")
df[-1]
# Out:
#     Rank            Name    Played for  Highest rating  Year
# 0      1        Umar Gul      Pakistan             857  2009
# 1      2   Samuel Badree   West Indies             855  2014
# 2      3  Daniel Vettori   New Zealand             850  2010
# 3      4    Sunil Narine   West Indies             817  2013
# 4      5     Rashid Khan   Afghanistan             816  2018
# 5      6   Shahid Afridi      Pakistan             814  2009
# 6      7     Imran Tahir  South Africa             795  2017
# 7      8     Saeed Ajmal      Pakistan             788  2012
# 8      9      Imad Wasim      Pakistan             780  2017
# 9     10     Shadab Khan      Pakistan             769  2018
# 10    10      Shaun Tait     Australia             769  2010
